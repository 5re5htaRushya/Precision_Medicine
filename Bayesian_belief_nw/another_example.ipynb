# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy 
import pandas 
import collections
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
df = pandas.read_csv('Training.csv')

# %%
class FungusClassifier(object):
    """Infers a hidden variable and uses Bayesian classification to predict whether a fungus is 
    edible or poisonous"""
    def __init__(self,filename):
        data=pandas.read_csv(filename,index_col=False)
        clusters=[]
        for (i,row) in data.iterrows():
            best=-1
            sim=0.5
            for (j,cluster) in enumerate(clusters):
                x=sum(cluster[key][value]/sum(cluster[key].values())
                      for (key,value) in row.iteritems())/(data.shape[1])
                if x>sim:
                    best=j
                    sim=x
            if best==-1:
                clusters.append(collections.defaultdict(lambda: collections.defaultdict(float)))
                print(i+1,'rows analysed',len(clusters),'clusters found')
            for (key,value) in row.iteritems():
                clusters[best][key][value]+=1.0
        index=[]
        for column in data.columns:
            index.extend([(column,value) for value in data[column].unique()])
        self.probabilities=pandas.DataFrame({(key,value):[cluster[key][value]+1.0 for cluster in clusters]
                                            for (key,value) in index}).T
        self.prior=self.probabilities.sum(axis=0)
        self.prior/=self.prior.sum()
        self.edibility_prior=self.probabilities.loc['class'].sum(axis=1)
        self.edibility_prior/=self.edibility_prior.sum()
        def normalize(group):
            return group.div(group.sum(axis=0),axis='columns')
        self.probabilities=self.probabilities.groupby(axis=0,level=0).apply(normalize)
        
    def __call__(self,**kwargs):
        "Estimates the probability that a fungus is edible given the features in kwargs"
        category=self.prior.copy()
        for (key,value) in kwargs.items():
            category*=self.probabilities.loc[(key,value)]
            category/=category.sum()
        result=self.edibility_prior*((self.probabilities.loc['class']*category).sum(axis=1))
        return result/result.sum()
    
    def test(self,filename):
        """Produces KDE plots of the estimated probability"""
        data=pandas.read_csv(filename,index_col=False)
        observables=[column for column in data.columns if column!='class']
        results=pandas.DataFrame([self(**row) for (i,row) in data[observables].iterrows()])
        results.loc[:,'class']=data['class']
        return results

# %%
BBN=FungusClassifier('mushrooms.csv')
# Out:
# 1 rows analysed 1 clusters found
# 15 rows analysed 2 clusters found
# 1817 rows analysed 3 clusters found
# 3985 rows analysed 4 clusters found
# 4024 rows analysed 5 clusters found
# 4077 rows analysed 6 clusters found
# 4195 rows analysed 7 clusters found
# 6039 rows analysed 8 clusters found
# 6416 rows analysed 9 clusters found
# 6913 rows analysed 10 clusters found
# 6968 rows analysed 11 clusters found

# %%
data=pandas.read_csv('mushrooms.csv',index_col=False)
clusters=[]
for (i,row) in data.iterrows():
    best=-1
    sim=0.5
    for (j,cluster) in enumerate(clusters):
        x=sum(cluster[key][value]/sum(cluster[key].values()) for (key,value) in row.iteritems())/(data.shape[1])
        if x>sim:
            best=j
            sim=x
    if best==-1:
        clusters.append(collections.defaultdict(lambda: collections.defaultdict(float)))
        print(i+1,'rows analysed',len(clusters),'clusters found')
    for (key,value) in row.iteritems():
        clusters[best][key][value]+=1.0
# Out:
# 1 rows analysed 1 clusters found
# 15 rows analysed 2 clusters found
# 1817 rows analysed 3 clusters found
# 3985 rows analysed 4 clusters found
# 4024 rows analysed 5 clusters found
# 4077 rows analysed 6 clusters found
# 4195 rows analysed 7 clusters found
# 6039 rows analysed 8 clusters found
# 6416 rows analysed 9 clusters found
# 6913 rows analysed 10 clusters found
# 6968 rows analysed 11 clusters found

# %%
clusters
# Out:
# [defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'p': 426.0, 'e': 1576.0}),
#               'cap-shape': defaultdict(float,
#                           {'x': 1085.0,
#                            'b': 257.0,
#                            's': 1.0,
#                            'f': 659.0,
#                            'k': 0.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'s': 488.0, 'y': 1441.0, 'f': 73.0, 'g': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'n': 512.0,
#                            'y': 357.0,
#                            'w': 447.0,
#                            'g': 337.0,
#                            'e': 289.0,
#                            'p': 58.0,
#                            'b': 2.0,
#                            'u': 0.0,
#                            'c': 0.0,
#                            'r': 0.0}),
#               'bruises': defaultdict(float, {'t': 1836.0, 'f': 166.0}),
#               'odor': defaultdict(float,
#                           {'p': 256.0,
#                            'a': 356.0,
#                            'l': 353.0,
#                            'n': 868.0,
#                            'f': 5.0,
#                            'c': 164.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 2002.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 1923.0, 'w': 79.0}),
#               'gill-size': defaultdict(float, {'n': 427.0, 'b': 1575.0}),
#               'gill-color': defaultdict(float,
#                           {'k': 194.0,
#                            'n': 518.0,
#                            'g': 170.0,
#                            'p': 385.0,
#                            'w': 478.0,
#                            'h': 1.0,
#                            'u': 256.0,
#                            'e': 0.0,
#                            'b': 0.0,
#                            'r': 0.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'e': 1126.0, 't': 876.0}),
#               'stalk-root': defaultdict(float,
#                           {'e': 258.0,
#                            'c': 512.0,
#                            'b': 1040.0,
#                            'r': 192.0,
#                            '?': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'s': 1999.0, 'f': 3.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'s': 1809.0, 'f': 1.0, 'y': 192.0, 'k': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'w': 1426.0,
#                            'g': 288.0,
#                            'p': 288.0,
#                            'n': 0.0,
#                            'b': 0.0,
#                            'e': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'w': 1425.0,
#                            'p': 288.0,
#                            'g': 289.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'e': 0.0,
#                            'y': 0.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 2002.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 2002.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 2002.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'p': 2001.0,
#                            'e': 1.0,
#                            'l': 0.0,
#                            'f': 0.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'k': 994.0,
#                            'n': 1002.0,
#                            'u': 0.0,
#                            'h': 5.0,
#                            'w': 1.0,
#                            'r': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'s': 569.0,
#                            'n': 256.0,
#                            'a': 1.0,
#                            'v': 646.0,
#                            'y': 529.0,
#                            'c': 1.0}),
#               'habitat': defaultdict(float,
#                           {'u': 131.0,
#                            'g': 484.0,
#                            'm': 256.0,
#                            'd': 1034.0,
#                            'p': 96.0,
#                            'w': 0.0,
#                            'l': 1.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'e': 1816.0, 'p': 21.0}),
#               'cap-shape': defaultdict(float,
#                           {'x': 911.0,
#                            's': 31.0,
#                            'f': 895.0,
#                            'b': 0.0,
#                            'k': 0.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'f': 1408.0, 's': 429.0, 'y': 0.0, 'g': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'n': 592.0,
#                            'g': 602.0,
#                            'w': 307.0,
#                            'y': 43.0,
#                            'e': 287.0,
#                            'p': 6.0,
#                            'b': 0.0,
#                            'u': 0.0,
#                            'c': 0.0,
#                            'r': 0.0}),
#               'bruises': defaultdict(float, {'f': 883.0, 't': 954.0}),
#               'odor': defaultdict(float,
#                           {'n': 1725.0,
#                            'p': 0.0,
#                            'a': 44.0,
#                            'l': 47.0,
#                            'f': 0.0,
#                            'c': 21.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 1837.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'w': 879.0, 'c': 958.0}),
#               'gill-size': defaultdict(float, {'b': 1630.0, 'n': 207.0}),
#               'gill-color': defaultdict(float,
#                           {'n': 466.0,
#                            'k': 214.0,
#                            'w': 245.0,
#                            'g': 26.0,
#                            'p': 471.0,
#                            'h': 192.0,
#                            'u': 223.0,
#                            'e': 0.0,
#                            'b': 0.0,
#                            'r': 0.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'t': 1721.0, 'e': 116.0}),
#               'stalk-root': defaultdict(float,
#                           {'e': 862.0,
#                            'c': 0.0,
#                            'b': 975.0,
#                            'r': 0.0,
#                            '?': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'s': 1453.0, 'f': 384.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'f': 384.0, 's': 1453.0, 'y': 0.0, 'k': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'w': 1261.0,
#                            'g': 288.0,
#                            'p': 288.0,
#                            'n': 0.0,
#                            'b': 0.0,
#                            'e': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'w': 1262.0,
#                            'p': 288.0,
#                            'g': 287.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'e': 0.0,
#                            'y': 0.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 1837.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 1837.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 1837.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'e': 767.0,
#                            'p': 1070.0,
#                            'l': 0.0,
#                            'f': 0.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'k': 874.0,
#                            'n': 915.0,
#                            'u': 48.0,
#                            'h': 0.0,
#                            'w': 0.0,
#                            'r': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'a': 383.0,
#                            'y': 479.0,
#                            's': 392.0,
#                            'v': 583.0,
#                            'n': 0.0,
#                            'c': 0.0}),
#               'habitat': defaultdict(float,
#                           {'g': 767.0,
#                            'u': 95.0,
#                            'm': 0.0,
#                            'd': 975.0,
#                            'p': 0.0,
#                            'w': 0.0,
#                            'l': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'p': 1304.0, 'e': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'x': 655.0,
#                            'f': 649.0,
#                            'b': 0.0,
#                            'k': 0.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'f': 655.0, 's': 1.0, 'y': 648.0, 'g': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'g': 656.0,
#                            'n': 0.0,
#                            'w': 0.0,
#                            'e': 0.0,
#                            'y': 648.0,
#                            'p': 0.0,
#                            'b': 0.0,
#                            'u': 0.0,
#                            'c': 0.0,
#                            'r': 0.0}),
#               'bruises': defaultdict(float, {'f': 1303.0, 't': 1.0}),
#               'odor': defaultdict(float,
#                           {'f': 1297.0,
#                            'n': 0.0,
#                            'p': 0.0,
#                            'l': 0.0,
#                            'a': 0.0,
#                            'c': 7.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 1304.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 1301.0, 'w': 3.0}),
#               'gill-size': defaultdict(float, {'b': 1297.0, 'n': 7.0}),
#               'gill-color': defaultdict(float,
#                           {'h': 432.0,
#                            'k': 0.0,
#                            'p': 435.0,
#                            'n': 0.0,
#                            'w': 0.0,
#                            'u': 1.0,
#                            'g': 436.0,
#                            'e': 0.0,
#                            'b': 0.0,
#                            'r': 0.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'e': 1303.0, 't': 1.0}),
#               'stalk-root': defaultdict(float,
#                           {'b': 1304.0,
#                            'e': 0.0,
#                            'c': 0.0,
#                            'r': 0.0,
#                            '?': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'k': 1296.0, 'f': 1.0, 's': 7.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'k': 1296.0, 's': 7.0, 'f': 1.0, 'y': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'n': 432.0,
#                            'w': 8.0,
#                            'g': 0.0,
#                            'p': 432.0,
#                            'b': 432.0,
#                            'e': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'b': 432.0,
#                            'w': 8.0,
#                            'g': 0.0,
#                            'p': 432.0,
#                            'n': 432.0,
#                            'e': 0.0,
#                            'y': 0.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 1304.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 1304.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 1304.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'l': 1296.0,
#                            'e': 0.0,
#                            'p': 8.0,
#                            'f': 0.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'h': 1297.0,
#                            'n': 3.0,
#                            'k': 4.0,
#                            'u': 0.0,
#                            'w': 0.0,
#                            'r': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'y': 648.0,
#                            'a': 0.0,
#                            's': 2.0,
#                            'v': 654.0,
#                            'n': 0.0,
#                            'c': 0.0}),
#               'habitat': defaultdict(float,
#                           {'g': 432.0,
#                            'd': 439.0,
#                            'u': 1.0,
#                            'm': 0.0,
#                            'p': 432.0,
#                            'w': 0.0,
#                            'l': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'e': 485.0, 'p': 1.0}),
#               'cap-shape': defaultdict(float,
#                           {'x': 163.0,
#                            'f': 66.0,
#                            'b': 97.0,
#                            'k': 160.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'y': 99.0, 'f': 144.0, 's': 243.0, 'g': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'b': 49.0,
#                            'g': 145.0,
#                            'y': 0.0,
#                            'e': 48.0,
#                            'n': 49.0,
#                            'w': 144.0,
#                            'p': 49.0,
#                            'u': 0.0,
#                            'c': 2.0,
#                            'r': 0.0}),
#               'bruises': defaultdict(float, {'t': 198.0, 'f': 288.0}),
#               'odor': defaultdict(float,
#                           {'n': 486.0,
#                            'f': 0.0,
#                            'c': 0.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 486.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 198.0, 'w': 288.0}),
#               'gill-size': defaultdict(float, {'b': 486.0, 'n': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'e': 96.0,
#                            'g': 97.0,
#                            'p': 96.0,
#                            'h': 0.0,
#                            'u': 0.0,
#                            'n': 0.0,
#                            'w': 197.0,
#                            'b': 0.0,
#                            'r': 0.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'e': 486.0, 't': 0.0}),
#               'stalk-root': defaultdict(float,
#                           {'?': 480.0, 'b': 6.0, 'c': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'s': 342.0, 'k': 144.0, 'f': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'s': 342.0, 'k': 144.0, 'f': 0.0, 'y': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'e': 96.0,
#                            'n': 0.0,
#                            'p': 0.0,
#                            'w': 390.0,
#                            'b': 0.0,
#                            'g': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'w': 390.0,
#                            'p': 0.0,
#                            'n': 0.0,
#                            'b': 0.0,
#                            'g': 0.0,
#                            'e': 96.0,
#                            'y': 0.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 486.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 486.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'t': 486.0, 'o': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'e': 192.0,
#                            'l': 0.0,
#                            'p': 294.0,
#                            'f': 0.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'w': 485.0,
#                            'h': 0.0,
#                            'n': 0.0,
#                            'k': 0.0,
#                            'r': 1.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'c': 192.0,
#                            'y': 2.0,
#                            'v': 4.0,
#                            's': 144.0,
#                            'n': 144.0}),
#               'habitat': defaultdict(float,
#                           {'w': 192.0,
#                            'g': 288.0,
#                            'd': 0.0,
#                            'p': 5.0,
#                            'l': 0.0,
#                            'm': 1.0,
#                            'u': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'p': 1760.0, 'e': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'x': 584.0,
#                            'f': 584.0,
#                            'b': 8.0,
#                            'k': 584.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'y': 880.0, 's': 864.0, 'f': 16.0, 'g': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'e': 864.0,
#                            'g': 0.0,
#                            'b': 0.0,
#                            'y': 16.0,
#                            'w': 0.0,
#                            'n': 880.0,
#                            'p': 0.0,
#                            'u': 0.0,
#                            'c': 0.0,
#                            'r': 0.0}),
#               'bruises': defaultdict(float, {'f': 1760.0, 't': 0.0}),
#               'odor': defaultdict(float,
#                           {'y': 576.0,
#                            'f': 576.0,
#                            'c': 0.0,
#                            'n': 32.0,
#                            's': 576.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 1760.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 1760.0, 'w': 0.0}),
#               'gill-size': defaultdict(float, {'n': 1760.0, 'b': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'b': 1728.0,
#                            'h': 0.0,
#                            'g': 0.0,
#                            'u': 0.0,
#                            'p': 0.0,
#                            'w': 32.0,
#                            'n': 0.0,
#                            'e': 0.0,
#                            'r': 0.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'t': 1728.0, 'e': 32.0}),
#               'stalk-root': defaultdict(float,
#                           {'?': 1760.0, 'b': 0.0, 'c': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'k': 896.0, 's': 864.0, 'f': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'s': 864.0, 'k': 864.0, 'f': 0.0, 'y': 32.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'w': 896.0,
#                            'n': 0.0,
#                            'p': 864.0,
#                            'g': 0.0,
#                            'b': 0.0,
#                            'e': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'w': 864.0,
#                            'n': 16.0,
#                            'p': 864.0,
#                            'b': 0.0,
#                            'g': 0.0,
#                            'e': 0.0,
#                            'y': 16.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 1760.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 1760.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 1760.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'e': 1760.0,
#                            'l': 0.0,
#                            'p': 0.0,
#                            'f': 0.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'w': 1760.0,
#                            'h': 0.0,
#                            'n': 0.0,
#                            'k': 0.0,
#                            'r': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'v': 1760.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'c': 0.0,
#                            'n': 0.0}),
#               'habitat': defaultdict(float,
#                           {'p': 576.0,
#                            'g': 0.0,
#                            'd': 608.0,
#                            'l': 576.0,
#                            'm': 0.0,
#                            'u': 0.0,
#                            'w': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'e': 96.0, 'p': 4.0}),
#               'cap-shape': defaultdict(float,
#                           {'f': 41.0,
#                            'x': 40.0,
#                            'b': 0.0,
#                            'k': 18.0,
#                            'c': 1.0}),
#               'cap-surface': defaultdict(float,
#                           {'y': 75.0, 'f': 24.0, 's': 0.0, 'g': 1.0}),
#               'cap-color': defaultdict(float,
#                           {'u': 16.0,
#                            'n': 24.0,
#                            'y': 0.0,
#                            'g': 0.0,
#                            'e': 0.0,
#                            'w': 20.0,
#                            'b': 0.0,
#                            'c': 24.0,
#                            'p': 0.0,
#                            'r': 16.0}),
#               'bruises': defaultdict(float, {'f': 96.0, 't': 4.0}),
#               'odor': defaultdict(float,
#                           {'n': 100.0,
#                            'f': 0.0,
#                            'c': 0.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 100.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 48.0, 'w': 52.0}),
#               'gill-size': defaultdict(float, {'n': 100.0, 'b': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'h': 12.0,
#                            'u': 12.0,
#                            'p': 12.0,
#                            'g': 0.0,
#                            'n': 0.0,
#                            'w': 64.0,
#                            'b': 0.0,
#                            'e': 0.0,
#                            'r': 0.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'e': 100.0, 't': 0.0}),
#               'stalk-root': defaultdict(float,
#                           {'?': 48.0, 'b': 52.0, 'c': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'s': 76.0, 'k': 0.0, 'f': 24.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'f': 72.0, 's': 28.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'w': 100.0,
#                            'p': 0.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'g': 0.0,
#                            'e': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'w': 52.0,
#                            'p': 0.0,
#                            'b': 0.0,
#                            'n': 48.0,
#                            'g': 0.0,
#                            'e': 0.0,
#                            'y': 0.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 100.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 100.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 100.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'f': 48.0,
#                            'p': 4.0,
#                            'l': 0.0,
#                            'e': 48.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'h': 48.0,
#                            'n': 0.0,
#                            'k': 0.0,
#                            'w': 52.0,
#                            'r': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'y': 24.0,
#                            'v': 72.0,
#                            's': 0.0,
#                            'c': 4.0,
#                            'n': 0.0}),
#               'habitat': defaultdict(float,
#                           {'d': 48.0,
#                            'g': 0.0,
#                            'p': 0.0,
#                            'l': 52.0,
#                            'm': 0.0,
#                            'u': 0.0,
#                            'w': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'p': 356.0, 'e': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'f': 178.0,
#                            'x': 141.0,
#                            'k': 0.0,
#                            'b': 36.0,
#                            'c': 1.0}),
#               'cap-surface': defaultdict(float,
#                           {'s': 317.0, 'f': 0.0, 'y': 36.0, 'g': 3.0}),
#               'cap-color': defaultdict(float,
#                           {'b': 117.0,
#                            'e': 0.0,
#                            'n': 0.0,
#                            'g': 93.0,
#                            'p': 24.0,
#                            'y': 0.0,
#                            'w': 122.0,
#                            'r': 0.0,
#                            'u': 0.0,
#                            'c': 0.0}),
#               'bruises': defaultdict(float, {'t': 356.0, 'f': 0.0}),
#               'odor': defaultdict(float,
#                           {'f': 282.0,
#                            'n': 74.0,
#                            'y': 0.0,
#                            'c': 0.0,
#                            's': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 356.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 353.0, 'w': 3.0}),
#               'gill-size': defaultdict(float, {'b': 353.0, 'n': 3.0}),
#               'gill-color': defaultdict(float,
#                           {'w': 121.0,
#                            'u': 0.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'g': 23.0,
#                            'h': 95.0,
#                            'p': 93.0,
#                            'e': 0.0,
#                            'r': 24.0,
#                            'y': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'t': 282.0, 'e': 74.0}),
#               'stalk-root': defaultdict(float,
#                           {'b': 356.0, '?': 0.0, 'c': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'f': 140.0, 's': 216.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'f': 142.0, 's': 214.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'w': 356.0,
#                            'p': 0.0,
#                            'g': 0.0,
#                            'n': 0.0,
#                            'b': 0.0,
#                            'e': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'w': 356.0,
#                            'p': 0.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'g': 0.0,
#                            'e': 0.0,
#                            'y': 0.0,
#                            'o': 0.0,
#                            'c': 0.0}),
#               'veil-type': defaultdict(float, {'p': 356.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 356.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 285.0, 't': 71.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'p': 356.0,
#                            'e': 0.0,
#                            'l': 0.0,
#                            'f': 0.0,
#                            'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'h': 282.0,
#                            'n': 0.0,
#                            'w': 3.0,
#                            'k': 0.0,
#                            'r': 71.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'b': 0.0}),
#               'population': defaultdict(float,
#                           {'s': 141.0,
#                            'y': 0.0,
#                            'v': 212.0,
#                            'c': 3.0,
#                            'n': 0.0}),
#               'habitat': defaultdict(float,
#                           {'u': 141.0,
#                            'd': 0.0,
#                            'l': 3.0,
#                            'p': 0.0,
#                            'g': 177.0,
#                            'w': 0.0,
#                            'm': 35.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'e': 192.0, 'p': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'b': 48.0,
#                            'f': 48.0,
#                            'x': 48.0,
#                            'k': 48.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'s': 192.0, 'y': 0.0, 'f': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'n': 192.0,
#                            'e': 0.0,
#                            'w': 0.0,
#                            'c': 0.0,
#                            'g': 0.0,
#                            'y': 0.0,
#                            'p': 0.0}),
#               'bruises': defaultdict(float, {'f': 192.0, 't': 0.0}),
#               'odor': defaultdict(float,
#                           {'n': 192.0,
#                            'y': 0.0,
#                            's': 0.0,
#                            'f': 0.0,
#                            'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'a': 192.0, 'f': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 192.0, 'w': 0.0}),
#               'gill-size': defaultdict(float, {'b': 192.0, 'n': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'y': 64.0,
#                            'b': 0.0,
#                            'o': 64.0,
#                            'w': 0.0,
#                            'g': 0.0,
#                            'p': 0.0,
#                            'n': 64.0}),
#               'stalk-shape': defaultdict(float, {'e': 192.0, 't': 0.0}),
#               'stalk-root': defaultdict(float,
#                           {'?': 192.0, 'b': 0.0, 'c': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'s': 192.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'s': 192.0, 'k': 0.0, 'y': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'o': 192.0,
#                            'p': 0.0,
#                            'w': 0.0,
#                            'c': 0.0,
#                            'y': 0.0,
#                            'n': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'o': 192.0,
#                            'p': 0.0,
#                            'w': 0.0,
#                            'c': 0.0,
#                            'y': 0.0,
#                            'n': 0.0}),
#               'veil-type': defaultdict(float, {'p': 192.0}),
#               'veil-color': defaultdict(float,
#                           {'n': 96.0, 'w': 0.0, 'o': 96.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 192.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float,
#                           {'p': 192.0, 'e': 0.0, 'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'n': 48.0,
#                            'w': 0.0,
#                            'o': 48.0,
#                            'y': 48.0,
#                            'b': 48.0}),
#               'population': defaultdict(float,
#                           {'c': 96.0,
#                            'v': 96.0,
#                            'n': 0.0,
#                            's': 0.0,
#                            'y': 0.0}),
#               'habitat': defaultdict(float,
#                           {'l': 192.0, 'd': 0.0, 'p': 0.0, 'g': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'p': 36.0, 'e': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'x': 12.0,
#                            'f': 12.0,
#                            'k': 12.0,
#                            'b': 0.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'y': 36.0, 's': 0.0, 'f': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'e': 12.0,
#                            'n': 12.0,
#                            'w': 0.0,
#                            'g': 0.0,
#                            'c': 12.0,
#                            'y': 0.0,
#                            'p': 0.0}),
#               'bruises': defaultdict(float, {'f': 36.0, 't': 0.0}),
#               'odor': defaultdict(float,
#                           {'m': 36.0, 'y': 0.0, 's': 0.0, 'f': 0.0, 'n': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 18.0, 'a': 18.0}),
#               'gill-spacing': defaultdict(float, {'c': 36.0, 'w': 0.0}),
#               'gill-size': defaultdict(float, {'b': 36.0, 'n': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'w': 18.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'g': 0.0,
#                            'p': 0.0,
#                            'o': 0.0,
#                            'y': 18.0}),
#               'stalk-shape': defaultdict(float, {'e': 36.0, 't': 0.0}),
#               'stalk-root': defaultdict(float,
#                           {'c': 36.0, '?': 0.0, 'b': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'k': 36.0, 's': 0.0, 'y': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'y': 36.0, 'k': 0.0, 's': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'c': 36.0,
#                            'p': 0.0,
#                            'w': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'n': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'c': 36.0,
#                            'p': 0.0,
#                            'w': 0.0,
#                            'o': 0.0,
#                            'y': 0.0,
#                            'n': 0.0}),
#               'veil-type': defaultdict(float, {'p': 36.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 36.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'n': 36.0, 'o': 0.0, 't': 0.0}),
#               'ring-type': defaultdict(float, {'n': 36.0, 'e': 0.0, 'p': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'w': 36.0, 'y': 0.0, 'o': 0.0, 'b': 0.0, 'n': 0.0}),
#               'population': defaultdict(float,
#                           {'c': 36.0, 'v': 0.0, 'n': 0.0, 's': 0.0, 'y': 0.0}),
#               'habitat': defaultdict(float,
#                           {'d': 36.0, 'p': 0.0, 'l': 0.0, 'g': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'p': 8.0, 'e': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'b': 2.0, 'x': 0.0, 'k': 2.0, 'f': 2.0, 'c': 2.0}),
#               'cap-surface': defaultdict(float,
#                           {'y': 8.0, 's': 0.0, 'f': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'y': 8.0,
#                            'e': 0.0,
#                            'g': 0.0,
#                            'n': 0.0,
#                            'p': 0.0,
#                            'w': 0.0,
#                            'c': 0.0}),
#               'bruises': defaultdict(float, {'f': 8.0, 't': 0.0}),
#               'odor': defaultdict(float,
#                           {'n': 8.0, 'f': 0.0, 's': 0.0, 'y': 0.0, 'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 8.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'w': 8.0, 'c': 0.0}),
#               'gill-size': defaultdict(float, {'n': 8.0, 'b': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'y': 4.0,
#                            'b': 0.0,
#                            'g': 0.0,
#                            'w': 4.0,
#                            'p': 0.0,
#                            'o': 0.0,
#                            'n': 0.0}),
#               'stalk-shape': defaultdict(float, {'e': 8.0, 't': 0.0}),
#               'stalk-root': defaultdict(float, {'c': 8.0, '?': 0.0, 'b': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'y': 8.0, 'k': 0.0, 's': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'y': 8.0, 's': 0.0, 'k': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'y': 8.0,
#                            'w': 0.0,
#                            'p': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'n': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'y': 8.0,
#                            'w': 0.0,
#                            'p': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'n': 0.0}),
#               'veil-type': defaultdict(float, {'p': 8.0}),
#               'veil-color': defaultdict(float,
#                           {'y': 8.0, 'w': 0.0, 'n': 0.0, 'o': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'o': 8.0, 't': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float, {'e': 8.0, 'p': 0.0, 'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'w': 8.0, 'n': 0.0, 'o': 0.0, 'b': 0.0, 'y': 0.0}),
#               'population': defaultdict(float,
#                           {'c': 8.0, 'v': 0.0, 'n': 0.0, 's': 0.0, 'y': 0.0}),
#               'habitat': defaultdict(float,
#                           {'l': 8.0, 'd': 0.0, 'g': 0.0, 'p': 0.0})}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'class': defaultdict(float, {'e': 43.0, 'p': 0.0}),
#               'cap-shape': defaultdict(float,
#                           {'b': 4.0,
#                            'f': 18.0,
#                            'k': 4.0,
#                            'x': 17.0,
#                            'c': 0.0}),
#               'cap-surface': defaultdict(float,
#                           {'s': 22.0, 'y': 21.0, 'f': 0.0}),
#               'cap-color': defaultdict(float,
#                           {'n': 23.0,
#                            'e': 0.0,
#                            'w': 0.0,
#                            'g': 7.0,
#                            'c': 6.0,
#                            'p': 7.0,
#                            'y': 0.0}),
#               'bruises': defaultdict(float, {'f': 16.0, 't': 27.0}),
#               'odor': defaultdict(float,
#                           {'n': 43.0, 'f': 0.0, 'y': 0.0, 's': 0.0, 'm': 0.0}),
#               'gill-attachment': defaultdict(float, {'f': 43.0, 'a': 0.0}),
#               'gill-spacing': defaultdict(float, {'c': 43.0, 'w': 0.0}),
#               'gill-size': defaultdict(float, {'b': 43.0, 'n': 0.0}),
#               'gill-color': defaultdict(float,
#                           {'w': 43.0,
#                            'b': 0.0,
#                            'n': 0.0,
#                            'p': 0.0,
#                            'y': 0.0,
#                            'g': 0.0,
#                            'o': 0.0}),
#               'stalk-shape': defaultdict(float, {'e': 43.0, 't': 0.0}),
#               'stalk-root': defaultdict(float,
#                           {'b': 43.0, '?': 0.0, 'c': 0.0}),
#               'stalk-surface-above-ring': defaultdict(float,
#                           {'y': 16.0, 's': 27.0, 'k': 0.0}),
#               'stalk-surface-below-ring': defaultdict(float,
#                           {'y': 16.0, 's': 27.0, 'k': 0.0}),
#               'stalk-color-above-ring': defaultdict(float,
#                           {'n': 16.0,
#                            'p': 0.0,
#                            'w': 27.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'stalk-color-below-ring': defaultdict(float,
#                           {'n': 16.0,
#                            'w': 27.0,
#                            'p': 0.0,
#                            'o': 0.0,
#                            'c': 0.0,
#                            'y': 0.0}),
#               'veil-type': defaultdict(float, {'p': 43.0}),
#               'veil-color': defaultdict(float,
#                           {'w': 43.0, 'n': 0.0, 'o': 0.0, 'y': 0.0}),
#               'ring-number': defaultdict(float,
#                           {'t': 43.0, 'o': 0.0, 'n': 0.0}),
#               'ring-type': defaultdict(float, {'p': 43.0, 'e': 0.0, 'n': 0.0}),
#               'spore-print-color': defaultdict(float,
#                           {'w': 43.0, 'n': 0.0, 'o': 0.0, 'b': 0.0, 'y': 0.0}),
#               'population': defaultdict(float,
#                           {'y': 30.0,
#                            'v': 13.0,
#                            's': 0.0,
#                            'c': 0.0,
#                            'n': 0.0}),
#               'habitat': defaultdict(float,
#                           {'d': 8.0, 'p': 35.0, 'l': 0.0, 'g': 0.0})})]

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.2'
