# %%
# Import required libraries
import pandas as pd
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from gensim import utils
#from gensim.models.doc2vec import LabeledSentence
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('questions.csv')

# Check for null values
df[df.isnull().any(axis=1)]

# Drop rows with null Values
df.drop(df[df.isnull().any(axis=1)].index,inplace=True)
df
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404346  404346  789792  789793
# 404347  404347  789794  789795
# 404348  404348  789796  789797
# 404349  404349  789798  789799
# 404350  404350  789800  789801
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404346  How many keywords are there in the Racket prog...
# 404347          Do you believe there is life after death?
# 404348                                  What is one coin?
# 404349  What is the approx annual cost of living while...
# 404350              What is like to have sex with cousin?
#
#                                                 question2  is_duplicate
# 0       What is the step by step guide to invest in sh...             0
# 1       What would happen if the Indian government sto...             0
# 2       How can Internet speed be increased by hacking...             0
# 3       Find the remainder when [math]23^{24}[/math] i...             0
# 4                 Which fish would survive in salt water?             0
# ...                                                   ...           ...
# 404346  How many keywords are there in PERL Programmin...             0
# 404347         Is it true that there is life after death?             1
# 404348                                  What's this coin?             0
# 404349  I am having little hairfall problem but I want...             0
# 404350      What is it like to have sex with your cousin?             0
#
# [404348 rows x 6 columns]

# %%
# Special Characters
review_text = re.sub(r"[^A-Za-z0-9(),!.?\'\`]", " ", final_text )
review_text = re.sub(r"\'s", " 's ", final_text )
review_text = re.sub(r"\'ve", " 've ", final_text )
review_text = re.sub(r"n\'t", " 't ", final_text )
review_text = re.sub(r"\'re", " 're ", final_text )
review_text = re.sub(r"\'d", " 'd ", final_text )
review_text = re.sub(r"\'ll", " 'll ", final_text )
review_text = re.sub(r",", " ", final_text )
review_text = re.sub(r"\.", " ", final_text )
review_text = re.sub(r"!", " ", final_text )
review_text = re.sub(r"\(", " ( ", final_text )
review_text = re.sub(r"\)", " ) ", final_text )
review_text = re.sub(r"\?", " ", final_text )
review_text = re.sub(r"\s{2,}", " ", final_text )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3adf80b4a2de> in <module>
#       1 # Special Characters
# ----> 2 review_text = re.sub(r"[^A-Za-z0-9(),!.?\'\`]", " ", final_text )
#       3 review_text = re.sub(r"\'s", " 's ", final_text )
#       4 review_text = re.sub(r"\'ve", " 've ", final_text )
#       5 review_text = re.sub(r"n\'t", " 't ", final_text )
#
# NameError: name 'final_text' is not defined

# %%
questions1 = list(df['question1'])
questions2 = list(df['question2'])

# %%
labeled_questions=[]
for i in range(0, len(df)+1):
    labeled_questions.append(TaggedDocument(questions1[i].split(), df[df.index == i].qid1))
    labeled_questions.append(TaggedDocument(questions2[i].split(), df[df.index == i].qid2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f9b17b259007> in <module>
#       2 for i in range(0, len(df)+1):
#       3     labeled_questions.append(TaggedDocument(questions1[i].split(), df[df.index == i].qid1))
# ----> 4     labeled_questions.append(TaggedDocument(questions2[i].split(), df[df.index == i].qid2))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in cmp_method(self, other)
#     142         else:
#     143             with np.errstate(all="ignore"):
# --> 144                 result = ops.comparison_op(self._values, np.asarray(other), op)
#     145
#     146         if is_bool_dtype(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     249             warnings.simplefilter("ignore", DeprecationWarning)
#     250             with np.errstate(all="ignore"):
# --> 251                 res_values = na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     252
#     253     return res_values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     141
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#     145         if is_cmp:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     231         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#     235
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     107         b_value = b
#     108
# --> 109         result = ne.evaluate(
#     110             f"a_value {op_str} b_value",
#     111             local_dict={"a_value": a_value, "b_value": b_value},
#
# C:\ProgramData\Anaconda3\lib\site-packages\numexpr\necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     832     _numexpr_last = dict(ex=compiled_ex, argnames=names, kwargs=kwargs)
#     833     with evaluate_lock:
# --> 834         return compiled_ex(*arguments, **kwargs)
#     835
#     836
#
# KeyboardInterrupt:

# %%
labeled_questions
# Out:
# [TaggedDocument(words=['What', 'is', 'the', 'step', 'by', 'step', 'guide', 'to', 'invest', 'in', 'share', 'market', 'in', 'india?'], tags=0    1
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'step', 'by', 'step', 'guide', 'to', 'invest', 'in', 'share', 'market?'], tags=0    2
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'story', 'of', 'Kohinoor', '(Koh-i-Noor)', 'Diamond?'], tags=1    3
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'would', 'happen', 'if', 'the', 'Indian', 'government', 'stole', 'the', 'Kohinoor', '(Koh-i-Noor)', 'diamond', 'back?'], tags=1    4
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'increase', 'the', 'speed', 'of', 'my', 'internet', 'connection', 'while', 'using', 'a', 'VPN?'], tags=2    5
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'Internet', 'speed', 'be', 'increased', 'by', 'hacking', 'through', 'DNS?'], tags=2    6
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'am', 'I', 'mentally', 'very', 'lonely?', 'How', 'can', 'I', 'solve', 'it?'], tags=3    7
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Find', 'the', 'remainder', 'when', '[math]23^{24}[/math]', 'is', 'divided', 'by', '24,23?'], tags=3    8
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'one', 'dissolve', 'in', 'water', 'quikly', 'sugar,', 'salt,', 'methane', 'and', 'carbon', 'di', 'oxide?'], tags=4    9
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'fish', 'would', 'survive', 'in', 'salt', 'water?'], tags=4    10
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Astrology:', 'I', 'am', 'a', 'Capricorn', 'Sun', 'Cap', 'moon', 'and', 'cap', 'rising...what', 'does', 'that', 'say', 'about', 'me?'], tags=5    11
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["I'm", 'a', 'triple', 'Capricorn', '(Sun,', 'Moon', 'and', 'ascendant', 'in', 'Capricorn)', 'What', 'does', 'this', 'say', 'about', 'me?'], tags=5    12
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Should', 'I', 'buy', 'tiago?'], tags=6    13
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'keeps', 'childern', 'active', 'and', 'far', 'from', 'phone', 'and', 'video', 'games?'], tags=6    14
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'be', 'a', 'good', 'geologist?'], tags=7    15
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'should', 'I', 'do', 'to', 'be', 'a', 'great', 'geologist?'], tags=7    16
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['When', 'do', 'you', 'use', 'シ', 'instead', 'of', 'し?'], tags=8    17
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['When', 'do', 'you', 'use', '"&"', 'instead', 'of', '"and"?'], tags=8    18
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Motorola', '(company):', 'Can', 'I', 'hack', 'my', 'Charter', 'Motorolla', 'DCX3400?'], tags=9    19
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'hack', 'Motorola', 'DCX3400', 'for', 'free', 'internet?'], tags=9    20
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Method', 'to', 'find', 'separation', 'of', 'slits', 'using', 'fresnel', 'biprism?'], tags=10    21
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'of', 'the', 'things', 'technicians', 'can', 'tell', 'about', 'the', 'durability', 'and', 'reliability', 'of', 'Laptops', 'and', 'its', 'components?'], tags=10    22
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'read', 'and', 'find', 'my', 'YouTube', 'comments?'], tags=11    23
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'see', 'all', 'my', 'Youtube', 'comments?'], tags=11    24
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'can', 'make', 'Physics', 'easy', 'to', 'learn?'], tags=12    25
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'you', 'make', 'physics', 'easy', 'to', 'learn?'], tags=12    26
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'was', 'your', 'first', 'sexual', 'experience', 'like?'], tags=13    27
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'was', 'your', 'first', 'sexual', 'experience?'], tags=13    28
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'laws', 'to', 'change', 'your', 'status', 'from', 'a', 'student', 'visa', 'to', 'a', 'green', 'card', 'in', 'the', 'US,', 'how', 'do', 'they', 'compare', 'to', 'the', 'immigration', 'laws', 'in', 'Canada?'], tags=14    29
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'laws', 'to', 'change', 'your', 'status', 'from', 'a', 'student', 'visa', 'to', 'a', 'green', 'card', 'in', 'the', 'US?', 'How', 'do', 'they', 'compare', 'to', 'the', 'immigration', 'laws', 'in', 'Japan?'], tags=14    30
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'would', 'a', 'Trump', 'presidency', 'mean', 'for', 'current', 'international', 'master’s', 'students', 'on', 'an', 'F1', 'visa?'], tags=15    31
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'will', 'a', 'Trump', 'presidency', 'affect', 'the', 'students', 'presently', 'in', 'US', 'or', 'planning', 'to', 'study', 'in', 'US?'], tags=15    32
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'does', 'manipulation', 'mean?'], tags=16    33
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'does', 'manipulation', 'means?'], tags=16    34
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'girls', 'want', 'to', 'be', 'friends', 'with', 'the', 'guy', 'they', 'reject?'], tags=17    35
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'guys', 'feel', 'after', 'rejecting', 'a', 'girl?'], tags=17    36
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'are', 'so', 'many', 'Quora', 'users', 'posting', 'questions', 'that', 'are', 'readily', 'answered', 'on', 'Google?'], tags=18    37
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'people', 'ask', 'Quora', 'questions', 'which', 'can', 'be', 'answered', 'easily', 'by', 'Google?'], tags=18    38
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'is', 'the', 'best', 'digital', 'marketing', 'institution', 'in', 'banglore?'], tags=19    39
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'is', 'the', 'best', 'digital', 'marketing', 'institute', 'in', 'Pune?'], tags=19    40
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'rockets', 'look', 'white?'], tags=20    41
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'are', 'rockets', 'and', 'boosters', 'painted', 'white?'], tags=20    42
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=["What's", 'causing', 'someone', 'to', 'be', 'jealous?'], tags=21    43
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'can', 'I', 'do', 'to', 'avoid', 'being', 'jealous', 'of', 'someone?'], tags=21    44
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'questions', 'should', 'not', 'ask', 'on', 'Quora?'], tags=22    45
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'question', 'should', 'I', 'ask', 'on', 'Quora?'], tags=22    46
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'much', 'is', '30', 'kV', 'in', 'HP?'], tags=23    47
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Where', 'can', 'I', 'find', 'a', 'conversion', 'chart', 'for', 'CC', 'to', 'horsepower?'], tags=23    48
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'does', 'it', 'mean', 'that', 'every', 'time', 'I', 'look', 'at', 'the', 'clock', 'the', 'numbers', 'are', 'the', 'same?'], tags=24    49
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'many', 'times', 'a', 'day', 'do', 'a', 'clock’s', 'hands', 'overlap?'], tags=24    50
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'tips', 'on', 'making', 'it', 'through', 'the', 'job', 'interview', 'process', 'at', 'Medicines?'], tags=25    51
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'tips', 'on', 'making', 'it', 'through', 'the', 'job', 'interview', 'process', 'at', 'Foundation', 'Medicine?'], tags=25    52
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'web', 'application?'], tags=26    53
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'web', 'application', 'framework?'], tags=26    54
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Does', 'society', 'place', 'too', 'much', 'importance', 'on', 'sports?'], tags=27    55
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'sports', 'contribute', 'to', 'the', 'society?'], tags=27    56
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'best', 'way', 'to', 'make', 'money', 'online?'], tags=28    57
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'best', 'way', 'to', 'ask', 'for', 'money', 'online?'], tags=28    58
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'should', 'I', 'prepare', 'for', 'CA', 'final', 'law?'], tags=29    59
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'one', 'should', 'know', 'that', 'he/she', 'completely', 'prepare', 'for', 'CA', 'final', 'exam?'], tags=29    60
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=["What's", 'one', 'thing', 'you', 'would', 'like', 'to', 'do', 'better?'], tags=30    61
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["What's", 'one', 'thing', 'you', 'do', 'despite', 'knowing', 'better?'], tags=30    62
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'special', 'cares', 'for', 'someone', 'with', 'a', 'nose', 'that', 'gets', 'stuffy', 'during', 'the', 'night?'], tags=31    63
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'keep', 'my', 'nose', 'from', 'getting', 'stuffy', 'at', 'night?'], tags=31    64
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'Game', 'of', 'Thrones', 'villain', 'would', 'be', 'the', 'most', 'likely', 'to', 'give', 'you', 'mercy?'], tags=32    65
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'Game', 'of', 'Thrones', 'villain', 'would', 'you', 'most', 'like', 'to', 'be', 'at', 'the', 'mercy', 'of?'], tags=32    66
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Does', 'the', 'United', 'States', 'government', 'still', 'blacklist', '(employment,', 'etc.)', 'some', 'United', 'States', 'citizens', 'because', 'their', 'political', 'views?'], tags=33    67
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'is', 'the', 'average', 'speed', 'of', 'gas', 'molecules', 'determined?'], tags=33    68
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'travel', 'website', 'in', 'spain?'], tags=34    69
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'travel', 'website?'], tags=34    70
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'some', 'people', 'think', 'Obama', 'will', 'try', 'to', 'take', 'their', 'guns', 'away?'], tags=35    71
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Has', 'there', 'been', 'a', 'gun', 'control', 'initiative', 'to', 'take', 'away', 'guns', 'people', 'already', 'own?'], tags=35    72
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=["I'm", 'a', '19-year-old.', 'How', 'can', 'I', 'improve', 'my', 'skills', 'or', 'what', 'should', 'I', 'do', 'to', 'become', 'an', 'entrepreneur', 'in', 'the', 'next', 'few', 'years?'], tags=36    73
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['I', 'am', 'a', '19', 'year', 'old', 'guy.', 'How', 'can', 'I', 'become', 'a', 'billionaire', 'in', 'the', 'next', '10', 'years?'], tags=36    74
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['When', 'a', 'girlfriend', 'asks', 'her', 'boyfriend', '"Why', 'did', 'you', 'choose', 'me?', 'What', 'makes', 'you', 'want', 'to', 'be', 'with', 'me?",', 'what', 'should', 'one', 'reply', 'to', 'her?'], tags=37    75
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['My', 'girlfriend', 'said', 'that', 'we', 'should', 'end', 'this', 'because', 'she', 'is', 'confused', 'about', 'her', 'feelings', 'for', 'me.', 'I', 'wished', 'her', 'well', 'and', 'disconnected.', 'Should', 'I', 'call', 'her', 'and', 'ask', 'her', 'if', 'she', 'wants', 'to', 'get', 'back', 'together?'], tags=37    76
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'we', 'prepare', 'for', 'UPSC?'], tags=38    77
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'prepare', 'for', 'civil', 'service?'], tags=38    78
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'stall', 'speed', 'and', 'AOA', 'of', 'an', 'f-14', 'with', 'wings', 'fully', 'swept', 'back?'], tags=39    79
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'did', 'aircraft', 'stop', 'using', 'variable-sweep', 'wings,', 'like', 'those', 'on', 'an', 'F-14?'], tags=39    80
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'Slavs', 'squat?'], tags=40    81
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Will', 'squats', 'make', 'my', 'legs', 'thicker?'], tags=40    82
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['When', 'can', 'I', 'expect', 'my', 'Cognizant', 'confirmation', 'mail?'], tags=41    83
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['When', 'can', 'I', 'expect', 'Cognizant', 'confirmation', 'mail?'], tags=41    84
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'I', 'make', '50,000', 'a', 'month', 'by', 'day', 'trading?'], tags=42    85
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'I', 'make', '30,000', 'a', 'month', 'by', 'day', 'trading?'], tags=42    86
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'being', 'a', 'good', 'kid', 'and', 'not', 'being', 'a', 'rebel', 'worth', 'it', 'in', 'the', 'long', 'run?'], tags=43    87
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'being', 'bored', 'good', 'for', 'a', 'kid?'], tags=43    88
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'universities', 'does', 'Rexnord', 'recruit', 'new', 'grads', 'from?', 'What', 'majors', 'are', 'they', 'looking', 'for?'], tags=44    89
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'universities', 'does', 'B&G', 'Foods', 'recruit', 'new', 'grads', 'from?', 'What', 'majors', 'are', 'they', 'looking', 'for?'], tags=44    90
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'quickest', 'way', 'to', 'increase', 'Instagram', 'followers?'], tags=45    91
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'we', 'increase', 'our', 'number', 'of', 'Instagram', 'followers?'], tags=45    92
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'did', 'Darth', 'Vader', 'fought', 'Darth', 'Maul', 'in', 'Star', 'Wars', 'Legends?'], tags=46    93
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Does', 'Quora', 'have', 'a', 'character', 'limit', 'for', 'profile', 'descriptions?'], tags=46    94
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'stages', 'of', 'breaking', 'up', 'between', 'couple?', 'I', 'mean,', 'what', 'happens', 'after', 'the', 'breaking', 'up', 'emotionally', 'whether', 'its', 'a', 'male', 'or', 'female?'], tags=47    95
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Who', 'is', 'affected', 'more', 'by', 'a', 'breakup,', 'the', 'boy', 'or', 'the', 'girl?'], tags=47    96
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'examples', 'of', 'products', 'that', 'can', 'be', 'make', 'from', 'crude', 'oil?'], tags=48    97
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'of', 'the', 'products', 'made', 'from', 'crude', 'oil?'], tags=48    98
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'make', 'friends.'], tags=49    99
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'to', 'make', 'friends', '?'], tags=49    100
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'Career', 'Launcher', 'good', 'for', 'RBI', 'Grade', 'B', 'preparation?'], tags=50    101
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'is', 'career', 'launcher', 'online', 'program', 'for', 'RBI', 'Grade', 'B?'], tags=50    102
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Will', 'a', 'Blu', 'Ray', 'play', 'on', 'a', 'regular', 'DVD', 'player?', 'If', 'so,', 'how?'], tags=51    103
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'you', 'play', 'a', 'Blu', 'Ray', 'DVD', 'on', 'a', 'regular', 'DVD', 'player?'], tags=51    104
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Nd', 'she', 'is', 'always', 'sad?'], tags=52    105
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Aerodynamically', 'what', 'happens', 'when', 'propellor', 'rotates?'], tags=52    106
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best/most', 'memorable', 'thing', "you've", 'ever', 'eaten', 'and', 'why?'], tags=53    107
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'most', 'delicious', 'dish', "you've", 'ever', 'eaten', 'and', 'why?'], tags=53    108
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'GST', 'affects', 'the', 'CAs', 'and', 'tax', 'officers?'], tags=54    109
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', "can't", 'I', 'do', 'my', 'homework?'], tags=54    110
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'difficult', 'is', 'it', 'get', 'into', 'RSI?'], tags=55    111
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Do', 'you', 'apply', 'for', 'programs', 'like', 'RSI', 'when', "you're", 'a', 'rising', 'senior?'], tags=55    112
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Who', 'is', 'israil', 'friend?'], tags=56    113
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'my', 'boyfriend', 'lying', 'about', 'his', 'true', 'feelings', 'for', 'his', 'friend', 'and', 'is', 'he', 'secretly', 'attracted', 'to', 'her?'], tags=56    114
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'good', 'rap', 'songs', 'to', 'dance', 'to?'], tags=57    115
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'of', 'the', 'best', 'rap', 'songs?'], tags=57    116
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['I', 'was', 'suddenly', 'logged', 'off', 'Gmail.', 'I', "can't", 'remember', 'my', 'Gmail', 'password', 'and', 'just', 'realized', 'the', 'recovery', 'email', 'is', 'no', 'longer', 'alive.', 'What', 'can', 'I', 'do?'], tags=58    117
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['I', "can't", 'remember', 'my', 'Gmail', 'password', 'or', 'my', 'recovery', 'email.', 'How', 'can', 'I', 'recover', 'my', 'e-mail?'], tags=58    118
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'best', 'ways', 'to', 'learn', 'French?'], tags=59    119
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'learn', 'french', 'genders?'], tags=59    120
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'download', 'content', 'from', 'a', 'kickass', 'torrent', 'without', 'registration?'], tags=60    121
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'Kickass', 'Torrents', 'trustworthy?'], tags=60    122
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'normal', 'to', 'have', 'a', 'dark', 'ring', 'around', 'the', 'iris', 'of', 'my', 'eye?'], tags=61    123
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'causes', 'a', 'dark', 'ring', 'around', 'the', 'iris?', 'How', 'should', 'it', 'be', 'treated?'], tags=61    124
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'is', 'the', 'new', 'Harry', 'Potter', 'book', "'Harry", 'Potter', 'and', 'the', 'Cursed', "Child'?"], tags=62    125
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'bad', 'is', 'the', 'new', 'book', 'by', 'J.K', 'Rowling?'], tags=62    126
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'I', 'always', 'get', 'depressed?'], tags=63    127
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'I', 'always', 'get', 'depressed', 'in', 'the', 'evening?'], tags=63    128
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Where', 'can', 'I', 'find', 'a', 'European', 'family', 'office', 'database?'], tags=64    129
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Where', 'do', 'I', 'find', 'a', 'U.S.', 'family', 'office', 'database?'], tags=64    130
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'Java', 'programming?', 'How', 'To', 'Learn', 'Java', 'Programming', 'Language', '?'], tags=65    131
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'learn', 'a', 'computer', 'language', 'like', 'java?'], tags=65    132
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'book', 'ever', 'made?'], tags=66    133
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'most', 'important', 'book', 'you', 'have', 'ever', 'read?'], tags=66    134
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'we', 'ever', 'store', 'energy', 'produced', 'in', 'lightning?'], tags=67    135
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'possible', 'to', 'store', 'the', 'energy', 'of', 'lightning?'], tags=67    136
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'your', 'review', 'of', 'Performance', 'Testing?'], tags=68    137
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'performance', 'testing?'], tags=68    138
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['At', 'what', 'cost', 'does', 'so', 'much', 'privacy', 'as', 'in', 'Germany', 'come?', 'What', 'else', 'is', 'lost', 'to', 'gain', 'so', 'much', 'privacy?'], tags=69    139
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Are', 'there', 'any', 'people', 'who', 'genuinely', 'enjoy', 'salad', 'with', 'no', 'dressing?'], tags=69    140
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'types', 'of', 'immunity?'], tags=70    141
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'different', 'types', 'of', 'immunity', 'in', 'our', 'body?'], tags=70    142
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'a', 'narcissistic', 'personality', 'disorder?'], tags=71    143
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'narcissistic', 'personality', 'disorder?'], tags=71    144
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'I', 'can', 'speak', 'English', 'fluently?'], tags=72    145
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'learn', 'to', 'speak', 'English', 'fluently?'], tags=72    146
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'helpful', 'is', "QuickBooks'", 'auto', 'data', 'recovery', 'support', 'phone', 'number', 'to', 'recover', 'your', 'corrupted', 'data', 'files?'], tags=73    147
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'quickbooks', 'customer', 'support', 'phone', 'number', 'USA?'], tags=73    148
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Who', 'is', 'the', 'richest', 'gambler', 'of', 'all', 'time', 'and', 'how', 'can', 'I', 'reach', 'his', 'level?'], tags=74    149
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Who', 'is', 'the', 'richest', 'gambler', 'of', 'all', 'time', 'and', 'how', 'can', 'I', 'reach', 'his', 'level', 'as', 'a', 'gambler?'], tags=74    150
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['If', 'I', 'fire', 'a', 'bullet', 'backward', 'from', 'an', 'aircraft', 'going', 'faster', 'than', 'the', 'bullet;', 'will', 'the', 'bullet', 'be', 'going', 'backwards?'], tags=75    151
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Do', 'bullets', 'travel', 'faster', 'than', 'the', 'speed', 'of', 'sound', 'when', 'shot', 'from', 'a', 'gun?', 'If', 'not,', 'is', 'it', 'possible?', 'If', 'they', 'do,', 'what', 'gun', 'and', 'how', 'much', 'devastation', 'occurs?'], tags=75    152
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'prevent', 'breast', 'cancer?'], tags=76    153
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'breast', 'cancer', 'preventable?'], tags=76    154
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'log', 'out', 'of', 'my', 'Gmail', 'account', 'on', 'my', "friend's", 'phone?'], tags=77    155
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'know', 'who', 'logged', 'in', 'to', 'my', 'Gmail', 'account?', '(by', 'telling', 'his', 'IP', 'address', 'or', 'device', 'name)?'], tags=77    156
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'make', 'money', 'through', 'the', 'Internet?'], tags=78    157
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'different', 'ways', 'to', 'make', 'money', 'online,', 'excluding', 'selling', 'things?'], tags=78    158
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'purpose', 'of', 'life?'], tags=79    159
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["What's", 'the', 'purpose', 'of', 'life?', 'What', 'is', 'life', 'actually', 'about?'], tags=79    160
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['When', 'will', 'the', 'BJP', 'government', 'strip', 'all', 'the', 'Muslims', 'and', 'the', 'Christians', 'of', 'the', 'Indian', 'citizenship', 'and', 'put', 'them', 'on', 'boats', 'like', 'the', "Rohingya's", 'of', 'Burma?'], tags=80    161
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'India', 'does', 'not', 'apply', 'the', '"Burma-Rohingya', 'model"', 'to', 'deport', 'illegal', 'Bangladeshis?'], tags=80    162
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'right', 'etiquette', 'for', 'wishing', 'a', 'Jehovah', 'Witness', 'happy', 'birthday?'], tags=81    163
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'important', 'is', 'it', 'to', 'be', 'the', 'first', 'person', 'to', 'wish', 'someone', 'a', 'happy', 'birthday?'], tags=81    164
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['If', 'someone', 'wants', 'to', 'open', 'a', 'commercial', 'FM', 'radio', 'station', 'in', 'any', 'city', 'of', 'India,', 'how', 'much', 'does', 'it', 'cost', 'and', 'what', 'is', 'the', 'procedure?'], tags=82    165
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['I', 'want', 'to', 'make', 'a', 'travel', 'commercial/clip', 'video', 'HD', ',', 'For', 'India', 'and', 'New', 'Zealand.', 'How', 'much', 'will', 'it', 'cost?'], tags=82    166
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'Swiss', 'despise', 'Asians?'], tags=83    167
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'technical', 'employees', 'despise', 'sales', 'people', 'so', 'much?'], tags=83    168
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'of', 'the', 'high', 'salary', 'income', 'jobs', 'in', 'the', 'field', 'of', 'biotechnology?'], tags=84    169
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'high', 'paying', 'jobs', 'for', 'a', 'fresher', 'with', 'an', 'M.Tech', 'in', 'biotechnology?'], tags=84    170
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'increase', 'my', 'height', 'after', '21', 'also?'], tags=85    171
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'height', 'increase', 'after', '25?'], tags=85    172
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'were', 'the', 'major', 'effects', 'of', 'the', 'cambodia', 'earthquake,', 'and', 'how', 'do', 'these', 'effects', 'compare', 'to', 'the', 'Kamchatca', 'earthquakes', 'in', '1952?'], tags=86    173
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'were', 'the', 'major', 'effects', 'of', 'the', 'cambodia', 'earthquake,', 'and', 'how', 'do', 'these', 'effects', 'compare', 'to', 'the', 'Valparaiso', 'earthquake', 'in', '1822?'], tags=86    174
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'difference', 'between', 'sincerity', 'and', 'fairness?'], tags=87    175
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["What's", 'the', 'difference', 'between', 'honest', 'and', 'sincere?'], tags=87    176
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'is', 'the', 'best', 'gaming', 'laptop', 'under', '60k', 'INR?'], tags=88    177
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'is', 'the', 'best', 'gaming', 'laptop', 'under', 'Rs', '60000?'], tags=88    178
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'your', 'review', 'of', 'The', 'Next', 'Warrior:', 'Proving', 'Grounds', '-', 'Part', '9?'], tags=89    179
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'your', 'review', 'of', 'The', 'Next', 'Warrior:', 'Proving', 'Grounds', '-', 'Part', '5?'], tags=89    180
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'reference', 'book', 'for', 'physics', 'class', '11th?'], tags=90    181
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'book', 'should', 'I', 'choose', 'for', 'reference', 'for', 'physics', 'and', 'chemistry', '(class', '11,', 'CBSE', 'board)?'], tags=90    182
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['National', 'Institute', 'of', 'Technology,', 'Kurukshetra:', 'How', 'is', 'the', 'social', 'life', 'at', 'NITK,', 'Surathkal?'], tags=91    183
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['National', 'Institute', 'of', 'Technology', 'Karnataka', '(NITK)', ',', 'Surathkal:', 'To', 'the', 'graduating', 'batch:', 'What', 'lessons', 'would', 'you', 'want', 'to', 'give', 'to', 'your', 'juniors', 'before', 'you', 'leave?'], tags=91    184
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'of', 'the', 'best', 'romantic', 'movies', 'in', 'English?'], tags=92    185
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'romantic', 'movie', 'you', 'have', 'ever', 'seen?'], tags=92    186
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'causes', 'a', 'nightmare?'], tags=93    187
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'causes', 'nightmares', 'that', 'seem', 'real?'], tags=93    188
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'abstract', 'expressionism', 'in', 'painting?'], tags=94    189
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'of', 'the', 'major', 'influences', 'of', 'abstract', 'expressionism?'], tags=94    190
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'does', '3D', 'printing', 'work?'], tags=95    191
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', '3D', 'printing', 'work?'], tags=95    192
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'was', 'it', 'like', 'to', 'attend', 'Caltech', 'with', 'Jeremy', 'Ehrhardt?'], tags=96    193
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Who', 'are', 'some', 'notable', 'folks', 'who', 'attended', 'Caltech?'], tags=96    194
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'did', 'harry', 'become', 'a', 'horcrux?'], tags=97    195
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'a', 'Horcrux?'], tags=97    196
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'best', 'associate', 'product', 'manager', '(APM)', 'programs', 'that', 'someone', 'in', 'their', 'early', '20s', 'can', 'join', 'to', 'learn', 'product', 'management', 'and', 'have', 'a', 'rewarding', 'career', 'in', 'the', 'company?'], tags=98    197
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'general', 'requirement', 'to', 'become', 'a', 'Product', 'Manager', 'or', 'a', 'Program', 'Manager', 'in', 'a', 'product', 'based', 'software', 'company?'], tags=98    198
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'is', 'the', 'number', 'for', 'Skype', 'at', '1-855-425-3768', 'always', 'busy?'], tags=99    199
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'could', 'I', 'get', 'Skype', 'to', 'work', 'on', 'an', 'android', '4.1.1', 'phone?'], tags=99    200
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Will', 'there', 'really', 'be', 'any', 'war', 'between', 'India', 'and', 'Pakistan', 'over', 'the', 'Uri', 'attack?', 'What', 'will', 'be', 'its', 'effects?'], tags=100    201
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Will', 'there', 'be', 'a', 'nuclear', 'war', 'between', 'India', 'and', 'Pakistan?'], tags=100    202
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Did', 'Ronald', 'Reagan', 'have', 'a', 'mannerism', 'in', 'his', 'speech?'], tags=101    203
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'did', 'Ronald', 'Reagan', 'react', 'to', '9/11?'], tags=101    204
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'were', 'the', 'war', 'strategies', 'of', 'the', 'Union', 'and', 'the', 'Confederates', 'during', 'the', 'Civil', 'War?'], tags=102    205
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'could', 'the', 'Confederates', 'have', 'possibly', 'defeated', 'Union', 'forces', 'at', 'Gettysburg', 'during', 'the', 'American', 'Civil', 'War?'], tags=102    206
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'is', 'the', 'best', 'fiction', 'novel', 'of', '2016?'], tags=103    207
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'are', 'some', 'of', 'the', 'best', 'fiction', 'novels?'], tags=103    208
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'I', 'recover', 'my', 'email', 'if', 'I', 'forgot', 'the', 'password?'], tags=104    209
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'should', 'I', 'do', 'if', 'I', 'forgot', 'my', 'email', 'password?'], tags=104    210
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Will', 'the', 'recent', 'demonetisation', 'results', 'in', 'higher', 'GDP?', 'If', 'so', 'how', 'much?'], tags=105    211
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'demonetisation', 'could', 'affect', 'the', 'GDP', 'of', 'India', 'in', 'both', 'short', 'run', 'and', 'long', 'run?'], tags=105    212
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Have', 'you', 'ever', 'heard', 'of', 'travel', 'hacking?'], tags=106    213
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'WhatsApp', 'be', 'hacked?'], tags=106    214
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=["What's", 'the', 'difference', 'between', 'love', 'and', 'pity?'], tags=107    215
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'difference', 'between', 'love', 'and', 'pity?'], tags=107    216
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'competitive', 'is', 'the', 'hiring', 'process', 'at', 'Republic', 'Bank?'], tags=108    217
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'competitive', 'is', 'the', 'hiring', 'process', 'at', 'S', '&', 'T', 'Bank?'], tags=108    218
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'Google', 'helps', 'in', 'spam', 'ranking', 'adjustment', 'of', 'the', 'search', 'results?'], tags=109    219
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'distribution', 'of', 'traffic', 'between', 'Google', 'organic', 'search', 'results?', 'e.g.', '#1', 'vs.', '#2', 'in', 'rankings,', 'first', 'page', 'vs.', 'second', 'page'], tags=109    220
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Where', 'can', 'I', 'watch', 'gonulcelen', 'with', 'english', 'subtitles?'], tags=110    221
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Where', 'can', 'I', 'watch', 'sarrainodu', 'with', 'subtitles?'], tags=110    222
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'USA', 'the', 'most', 'powerful', 'country', 'of', 'the', 'world?'], tags=111    223
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'is', 'the', 'USA', 'the', 'most', 'powerful', 'country', 'of', 'the', 'world?'], tags=111    224
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'you', 'obtain', 'an', 'instant', 'ulcer', 'pain', 'relief?'], tags=112    225
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'better', 'for', 'a', 'low', 'back', 'pain:', 'heat', 'or', 'ice?'], tags=112    226
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'do', 'you', 'think', 'China', 'food?'], tags=113    227
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'you', 'think', 'of', 'Chinese', 'food?'], tags=113    228
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'does', 'taking', 'advantage', 'of', 'someone', 'mean?'], tags=114    229
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'worse', 'to', 'take', 'advantage', 'of', 'someone', 'or', 'be', 'materialistic?'], tags=114    230
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'we', 'cry', 'when', 'we', 'are', 'happy', 'and', 'when', 'we', 'are', 'sad?'], tags=115    231
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'we', 'cry?'], tags=115    232
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'some', 'girls', 'like', 'to', 'stick', 'their', 'their', 'tongues', 'out', 'when', 'taking', 'pictures?'], tags=116    233
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'teen', 'girls', '(and', 'women', 'in', 'general)', 'allow', 'their', 'boyfriends', 'to', 'take', 'naked', 'pictures', 'of', 'them', 'in', 'this', 'day', 'and', '(digital)', 'age?'], tags=116    234
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Did', 'you', 'find', 'the', 'ending', 'of', 'the', 'novel', '"1984"', 'depressing?'], tags=117    235
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'Winston', 'and', 'Julia', 'differ', 'in', 'the', 'novel', '"1984"?', 'How', 'are', 'they', 'similar?'], tags=117    236
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'mind-blowing', 'computer', 'tools', 'that', 'exist', 'that', 'most', 'people', "don't", 'know', 'about?'], tags=118    237
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'mind-blowing', 'technologies', 'that', 'exist', 'that', 'most', 'people', "don't", 'know', 'about?'], tags=118    238
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Should', 'the', 'toothbrush', 'be', 'wet', 'or', 'dry', 'before', 'applying', 'the', 'toothpaste?'], tags=119    239
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'cheapest', 'toothpaste?'], tags=119    240
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'my', 'question', 'was', 'marked', 'as', 'needing', 'imrovement?'], tags=120    241
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'ask', 'a', 'question', 'without', 'getting', 'marked', 'as', '‘need', 'to', 'improve’?'], tags=120    242
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'difference', 'between', 'a', 'neutral', 'state', 'and', 'a', 'buffer', 'state?'], tags=121    243
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['If', 'every', 'state', 'of', 'the', 'USA', 'declared', 'war', 'against', 'each', 'other,', 'which', 'would', 'win?'], tags=121    244
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'mineral', 'holds', 'the', 'highest', 'electrical', 'charge?'], tags=122    245
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'mineral', 'can', 'hold', 'the', 'greatest', 'electrical', 'charge?'], tags=122    246
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'greatest', 'mystery', 'in', 'the', 'universe?'], tags=123    247
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'greatest', 'mystery', 'of', 'all', 'time?'], tags=123    248
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'alternative', 'to', 'machine', 'learning?'], tags=124    249
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'over-sample', 'a', 'multi-class', 'imbalance', 'data', 'set?'], tags=124    250
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'does', 'China', 'block', 'sanctions', 'at', 'the', 'UN', 'against', 'the', 'Jaish-e-Mohammad', '(JeM)', 'chief,', 'Masood', 'Azhar?'], tags=125    251
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'does', 'China', 'support', 'Masood', 'Azhar?'], tags=125    252
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'mean', 'of', 'future', 'budget?'], tags=126    253
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'meaning', 'of', 'the', 'future?'], tags=126    254
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'excessive', 'amounts', 'of', 'Vitamin', 'C', 'cause', 'me', 'to', 'have', 'a', 'miscarriage?'], tags=127    255
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'Vitamin', 'C', 'cause', 'a', 'miscarriage?'], tags=127    256
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'it', 'like', 'to', 'work', 'in', 'Asahi', 'India', 'Glass?', 'What', 'will', 'be', 'the', 'pay', 'scale', 'after', 'one', 'or', 'two', 'years?'], tags=128    257
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['When', 'will', 'we', 'get', 'the', 'Call', 'Letter', 'after', 'we', 'get', 'the', 'Letter', 'of', 'Intent', 'in', 'Asahi', 'India', 'Glass', 'recruitment?'], tags=128    258
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'access', 'Torbox', 'in', 'India?'], tags=129    259
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'access', 'Google.com', 'from', 'India?'], tags=129    260
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'yakshini', 'mantras?'], tags=130    261
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'a', 'Yantra', '&', 'Mantra?'], tags=130    262
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Was', 'six', 'party', 'talks', 'successful?'], tags=131    263
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'course', 'is', 'better', 'in', 'NICMAR?'], tags=131    264
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'register', 'my', 'domain', 'site', 'email?'], tags=132    265
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'you', 'register', 'a', '.an', 'domain?'], tags=132    266
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'normal', 'for', 'older', 'men', 'to', 'be', 'attracted', 'to', 'young', 'women?'], tags=133    267
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'am', 'I', 'attracted', 'to', 'older', 'men?'], tags=133    268
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'strongest', 'structure', 'or', 'strongest', 'shape', 'under', 'compression?'], tags=134    269
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'strongest', 'Kevlar', 'cord?'], tags=134    270
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Who', 'are', 'the', 'Rohingya', 'Muslims?'], tags=135    271
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Who', 'are', 'the', 'Rohingya', 'people?'], tags=135    272
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Does', 'it', 'matter', 'whether', 'humans', 'are', 'selfish', 'or', 'evil?'], tags=136    273
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Does', 'it', 'matter', 'whether', 'humanity', 'is', 'evil', 'or', 'not?'], tags=136    274
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Are', 'exocytosis', 'and', 'endocytosis', 'examples', 'of', 'active', 'or', 'passive', 'transport?'], tags=137    275
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'examples', 'of', 'passive', 'transport', 'in', 'cells?'], tags=137    276
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'i', 'get', 'hair', 'on', 'bald', 'head?'], tags=138    277
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['If', 'I', 'shave', 'my', 'head', 'for', '2', 'years', 'as', 'am', 'getting', 'bald', 'and', 'then', 'grew', 'my', 'hair,', 'will', 'the', 'hair', 'will', 'be', 'same', 'as', 'when', 'I', 'intially', 'have?', 'Or', 'I', 'loose', 'more', 'hair?'], tags=138    278
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'ideal', 'life', 'after', 'retirement?'], tags=139    279
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["What's", 'life', 'after', 'retirement?'], tags=139    280
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'our', 'stance', 'against', 'Pakistan?'], tags=140    281
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'stance', 'of', 'Pakistan', 'in', 'the', 'possession', 'of', 'weapons', 'of', 'mass', 'destruction', 'by', 'North', 'korea?', 'Does', 'it', 'support', 'DPRK', 'or', 'is', 'it', 'against', 'DPRK?'], tags=140    282
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'good', 'websites', 'for', 'escorts?'], tags=141    283
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'find', 'a', 'good', 'escort?'], tags=141    284
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'one', 'is', 'better', 'polo', 'diesel', 'or', 'grand', 'i10', 'petrol?'], tags=142    285
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'diet', 'for', 'a', 'growing', 'decathlete?'], tags=142    286
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Does', 'a', 'black', 'hole', 'have', 'mass?'], tags=143    287
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Does', 'a', 'black', 'hole', 'have', 'a', 'finite', 'mass?'], tags=143    288
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'Morgan', 'Freeman', 'correct', 'when', 'he', 'says', 'the', 'only', 'way', 'to', 'stop', 'racism,', 'is', 'to', 'stop', 'talking', 'about', 'it?'], tags=144    289
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'your', 'views', 'about', 'this', 'Morgan', 'Freeman', 'quote', 'about', 'Racism?'], tags=144    290
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Does', 'Fab', 'currently', 'offer', 'new', 'employees', 'stock', 'options', 'or', 'RSUs?'], tags=145    291
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Does', 'Uber', 'currently', 'offer', 'new', 'employees', 'stock', 'options', 'or', 'RSUs?'], tags=145    292
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'would', 'you', 'review', 'the', 'site', 'Waveclues?'], tags=146    293
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'there', 'a', 'good', 'pay', 'for', 'reviews', 'site', 'out', 'there?'], tags=146    294
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['In', 'how', 'many', 'ways', 'can', 'we', 'distribute', '10', 'identical', 'looking', 'pencils', 'to', '4', 'students', 'so', 'that', 'each', 'student', 'gets', 'at', 'least', 'one', 'pencil?'], tags=147    295
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['In', 'how', 'many', 'ways', '12', 'apples', 'can', 'be', 'distributed', 'among', '4', 'children', 'such', 'that', 'every', 'child', 'gets', 'at', 'least', '2', 'apples?'], tags=147    296
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'much', 'would', 'it', 'cost', 'to', 'hire', 'Jerry', 'Seinfeld', 'for', '1-2', 'hours?'], tags=148    297
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'much', 'on', 'average', 'would', 'it', 'cost', 'to', 'video', 'tape', 'a', '2', 'hour', 'presentation?'], tags=148    298
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', '7', 'days', 'too', 'late', 'for', 'rabies', 'vaccine', 'after', 'a', 'possible', 'non-bite', 'exposure?'], tags=149    299
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'I', 'take', 'rabies', 'injection', 'after', '1', 'day', 'of', 'dog', 'bite?'], tags=149    300
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'many', 'years', 'Britain', 'ruled', 'India?'], tags=150    301
#  Name: qid1, dtype: int64),
# ...
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'phone', 'to', 'buy', 'Moto', 'm', 'or', 'one', 'plus', '3t?'], tags=448    898
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'enter', 'a', 'new', 'email', 'ID', 'which', 'I', 'can', 'access', 'to', 'recover', 'my', 'Facebook', 'ID?'], tags=449    899
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['I', 'lost', 'all', 'my', 'ID.', 'I', 'am', 'adopted', 'and', "can't", 'access', 'my', 'original', 'birth', 'certificate.', 'How', 'do', 'I', 'replace', 'my', 'ID', 'without', 'even', 'a', 'birth', 'certificate?'], tags=449    900
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'we', 'can', 'travel', 'faster', 'than', 'light?'], tags=450    901
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'possible', 'to', 'travel', 'faster', 'than', 'light?'], tags=450    902
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'it', 'like', 'being', 'a', 'firefighter?'], tags=451    903
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["What's", 'it', 'like', 'to', 'be', 'a', 'firefighter?'], tags=451    904
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'factors', 'that', 'causes', 'data', 'inconsistency', 'in', 'distributed', 'platform/application?'], tags=452    905
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'main', 'data', 'platform?'], tags=452    906
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'differences', 'between', 'POCSO', 'and', 'sexual', 'offenses', 'in', 'the', 'IPC?'], tags=453    907
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Do', 'we', 'need', 'the', 'IPC', 'section', '375?'], tags=453    908
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'an', 'alternative', 'for', 'the', 'word', '"is"?'], tags=454    909
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'alternative', 'word', 'for', 'creative?'], tags=454    910
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'considered', 'an', 'illegal', 'screen', 'in', 'the', 'NBA?'], tags=455    911
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Shaquille', "O'Neal", 'considers', 'Tim', 'Duncan', 'a', 'power', 'forward', 'therefore', 'disqualifying', 'Duncan', 'from', 'the', 'NBA', 'great', 'big', 'men', 'discussion.', 'Does', "O'Neal", 'have', 'a', 'point?'], tags=455    912
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Nothing', 'excites', 'me', 'anymore.', 'How', 'do', 'I', 'regain', 'that', 'excitement?'], tags=456    913
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'I', 'feel', 'like', "I'm", 'excited', 'about', 'something', 'when', 'I', 'have', 'nothing', 'to', 'be', 'excited', 'about?'], tags=456    914
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'life', 'lessons', 'that', 'Batman', 'teaches', 'us?'], tags=457    915
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'life', 'lessons', 'you', 'can', 'learn', 'from', 'the', 'dark', 'knight?'], tags=457    916
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'you', 'stop', 'a', "criminal's", 'attempt', 'to', 'kidnap', 'you', 'so', 'you', 'escape', 'unharmed?'], tags=458    917
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'you', 'stop', 'a', "criminal's", 'attempt', 'to', 'kidnap', 'you', 'and', 'escape', 'unharmed?'], tags=458    918
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'sell', 'on', 'Amazon?'], tags=459    919
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'start', 'selling', 'on', 'Amazon?'], tags=459    920
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Daniel', 'Ek:', 'When', 'an', 'we', 'expect', 'Spotify', 'in', 'India?'], tags=460    921
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Daniel', 'Ek:', 'Are', 'there', 'any', 'future', 'plans', 'of', 'releasing', 'Spotify', 'in', 'India?'], tags=460    922
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'top', '10', 'books', 'one', 'should', 'read', 'in', 'his', 'or', 'her', 'early', '20s?'], tags=461    923
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'books', 'are', 'worth', 'reading', 'in', 'early', '20s?'], tags=461    924
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'book', 'should', 'I', 'start', 'with', 'for', 'the', 'GATE', 'preparation?'], tags=462    925
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'book', 'do', 'I', 'start', 'with', 'for', 'GATE', 'preparation?'], tags=462    926
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'does', 'the', 'phrase', '"He', 'who', 'does', 'not', 'love', 'abides', 'in', 'death"', 'exactly', 'mean?'], tags=463    927
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'does', 'the', 'phrase', '"love', 'begets', 'love"', 'mean?'], tags=463    928
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'similar', 'to', '4Shared?'], tags=464    929
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'similar', 'to', '4shared', 'but', 'better?'], tags=464    930
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'you', 'get', 'high', 'if', 'someone', 'touches', 'weed', 'and', 'then', 'you', 'shake', 'their', 'hand', 'and', 'then', 'you', 'eat', 'something', 'with', 'that', 'same', 'hand?'], tags=465    931
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['If', 'someone', 'grabs', 'you', 'by', 'your', 'shirt', 'with', 'both', 'their', 'hands', 'and', 'tells', 'you', 'to', 'shut', 'up,', 'is', 'that', 'assault', 'and', 'can', 'you', 'call', 'the', 'police?'], tags=465    932
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Considering', 'the', 'current', 'trend', 'of', 'information', 'technology', 'what', 'is', 'the', 'future', 'of', 'print', 'media?'], tags=466    933
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'this', "model's", 'name?', 'I', 'see', 'her', 'everywhere.'], tags=466    934
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'best', 'recipe', 'for', 'chicken', 'pizza?'], tags=467    935
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'good', 'pizza', 'recipes?'], tags=467    936
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'good', 'places', 'to', 'learn', 'mountaineering', 'in', 'India?'], tags=468    937
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'good', 'mountaineering', 'institutes', 'for', 'a', 'beginner', 'level', 'mountaineering', 'course?'], tags=468    938
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Do', 'new', 'table', 'tennis', 'balls', 'damage', 'rubbers?'], tags=469    939
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'you', 'unlock', 'a', 'car', 'with', 'a', 'tennis', 'ball?'], tags=469    940
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['My', 'new', 'Xbox', 'one', 'S', "can't", 'connect', 'to', 'internet', 'during', 'setup.', 'Any', 'solutions?'], tags=470    941
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'I', 'withdraw', 'my', 'money', 'from', 'any', 'branch', 'of', 'particular', 'bank', '.my', 'bank', 'is', 'bank', 'of', 'Baroda', 'I', 'have', 'no', 'Atm', 'card', 'and', 'cheque', 'book?'], tags=470    942
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'wrong', 'for', 'me', 'to', 'be', 'content', 'with', 'my', 'life?'], tags=471    943
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'a', 'cover', 'story?'], tags=471    944
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'gravity', 'only', 'a', 'theory?'], tags=472    945
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['According', 'to', 'the', 'M-theory,', 'there', 'are', '11', 'dimensions.', 'Why', 'are', 'only', '5', 'dimensions', 'in', 'regards', 'to', 'gravity', 'addressed', 'in', 'Interstellar?'], tags=472    946
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'could', 'I', 'become', 'a', 'fighter', 'pilot', 'when', 'I', 'have', 'less', 'than', 'the', 'required', 'eyesight?'], tags=473    947
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['I', 'have', 'terrible', 'eyesight.', 'Can', 'I', 'still', 'become', 'a', 'fighter', 'pilot', 'in', 'the', 'Air', 'Force?'], tags=473    948
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Operation', 'executive', 'salary', 'in', 'Infosys?'], tags=474    949
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'do', 'the', 'Wake', 'Back', 'To', 'Bed', 'lucid', 'dreaming', 'technique', 'when', 'I', 'think', 'I', 'have', 'restless', 'leg', 'syndrome', '(regardless,', 'my', 'legs', 'hurt', 'at', 'night.)?'], tags=474    950
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Have', 'cavemen', 'been', 'scientifically', 'tested?'], tags=475    951
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Have', 'mythical', 'creatures', 'been', 'scientifically', 'tested?'], tags=475    952
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'climate', 'change', 'be', 'reversed?'], tags=476    953
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'the', 'global', 'climate', 'change', 'be', 'reversed', 'or', 'halted?'], tags=476    954
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'should', 'ask', 'my', 'crush', 'for', 'her', 'number?'], tags=477    955
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'should', 'I', 'ask', 'my', 'crush?'], tags=477    956
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'do', 'I', 'believe', 'that', 'gravitation', 'force', 'exist?'], tags=478    957
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Does', 'gravitational', 'force', 'exists', 'in', 'all', 'planets?'], tags=478    958
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Did', 'Mahabharata', 'really', 'happen?'], tags=479    959
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Did', 'Mahabharata', 'really', 'happen', 'or', 'only', 'an', 'allegory', 'according', 'to', 'M.K.Gandhi?'], tags=479    960
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Can', 'Congress', 'stop', 'Presidents', 'from', 'starting', 'a', 'major', 'war?'], tags=480    961
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=["What's", 'a', 'good', 'source', 'to', 'purchase', 'Attorneys', 'eMail', 'addresses?', 'Thanks'], tags=480    962
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'safe', 'to', 'lose', '25', 'pounds', 'in', '1', 'month?'], tags=481    963
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'healthy', 'to', 'lose', '13', 'pounds', 'in', 'a', 'month?'], tags=481    964
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'cute', 'shounen', 'ai', 'series?'], tags=482    965
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['When', 'will', 'the', 'Pokémon', 'series', 'end?'], tags=482    966
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Why', 'are', 'police', 'lights', 'red', 'and', 'blue?'], tags=483    967
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'are', 'police', 'lights', 'red', 'and/or', 'blue?'], tags=483    968
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'post', 'a', 'question', 'that', 'was', 'marked', 'as', 'needing', 'improvement?'], tags=484    969
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'was', 'my', 'question', 'marked', 'as', '"needs', 'improvement?"'], tags=484    970
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Who', 'owns', 'nature?'], tags=485    971
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Who', 'owns', 'Natural', 'Factors?'], tags=485    972
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'can', 'I', 'install', 'OBB/data', 'file', 'on', 'an', 'Android?'], tags=486    973
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['I', 'want', 'to', 'install', 'EXE', 'extension', 'files', 'in', 'Android', 'mobile.', 'Is', 'it', 'possible?'], tags=486    974
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'garbage', 'value?', 'And', 'Why', 'do', 'we', 'get', 'garbage', 'value', 'in', 'c?'], tags=487    975
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'garbage', 'value', 'in', 'c?'], tags=487    976
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'do', 'I', 'prepare', 'for', 'software', 'interviews?'], tags=488    977
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'the', 'best', 'ways', 'to', 'prepare', 'for', 'software', 'interviews?'], tags=488    978
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Does', 'Rahul', 'Gandhi', 'have', 'any', 'chance', 'to', 'become', 'next', 'PM', 'of', 'India', 'after', 'Modi?'], tags=489    979
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Does', 'Rahul', 'Gandhi', 'have', 'chances', 'to', 'become', 'next', 'Pm', 'of', 'India', 'after', 'Modi?'], tags=489    980
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'noon', '12', 'am', 'or', '12', 'pm?'], tags=490    981
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Is', 'it', 'good', 'to', 'do', 'gym', 'at', 'morning', 'and', 'swimming', 'at', 'noon?'], tags=490    982
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'difference', 'between', 'a', 'comet', 'and', 'an', 'asteroid?'], tags=491    983
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'difference', 'between', 'asteroids', 'and', 'comets?'], tags=491    984
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'chocolate', 'milk', 'good', 'for', 'you?'], tags=492    985
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Why', 'is', 'unrefrigerated', 'milk', 'good', 'for', 'you?'], tags=492    986
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['How', 'should', 'I', 'study'], tags=493    987
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'are', 'some', 'tricks', 'to', 'study', 'effectively?'], tags=493    988
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'country', 'is', 'best', 'for', 'higher', 'education', 'and', 'work?'], tags=494    989
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'is', 'the', 'best', 'country', 'for', 'higher', 'education', 'after', 'USA', 'and', 'UK?'], tags=494    990
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'painting', 'on', 'this', 'image?'], tags=495    991
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'this', 'painting?'], tags=495    992
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Which', 'are', 'the', 'major', 'highways', 'in', 'California', 'and', 'how', 'are', 'they', 'compared', 'to', 'the', 'major', 'highways', 'in', 'Tennessee?'], tags=496    993
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Which', 'are', 'the', 'major', 'highways', 'in', 'California', 'and', 'how', 'are', 'they', 'compared', 'to', 'the', 'major', 'highways', 'in', 'Texas?'], tags=496    994
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=["What's", 'beyond', 'our', 'Universe?'], tags=497    995
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['If', 'space', 'is', 'expanding,', 'where', 'does', 'the', 'new', 'space', 'come', 'from?'], tags=497    996
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['Is', 'growing', 'of', 'hair', 'a', 'physical', 'or', 'a', 'chemical', 'change?'], tags=498    997
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['Can', 'a', 'bald', 'person', 'ever', 'grow', 'their', 'hair', 'back?'], tags=498    998
#  Name: qid2, dtype: int64),
#  TaggedDocument(words=['What', 'is', 'the', 'difference', 'between', 'culture', 'and', 'history?'], tags=499    999
#  Name: qid1, dtype: int64),
#  TaggedDocument(words=['How', 'is', 'chili', 'different', 'between', 'cultures?'], tags=499    1000
#  Name: qid2, dtype: int64),
#  ...]

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df = pd.DataFrame(columns=["ID","DESCRIPTION"], data=np.matrix([[10,"Cancel ASN WMS Cancel ASN"],
                                                                [11,"MAXPREDO Validation is corect"],
                                                                [12,"Move to QC"],
                                                                [13,"Cancel ASN WMS Cancel ASN"],
                                                                [14,"MAXPREDO Validation is right"],
                                                                [15,"Verify files are sent every hours for this interface from Optima"],
                                                                [16,"MAXPREDO Validation are correct"],
                                                                [17,"Move to QC"],
                                                                [18,"Verify files are not sent"]
                                                                ]))

corpus = list(df["DESCRIPTION"].values)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

threshold = 0.4

for x in range(0,X.shape[0]):
    for y in range(x,X.shape[0]):
        if(x!=y):
              if(cosine_similarity(X[x],X[y])>threshold):
                print(df["ID"][x],":",corpus[x])
                print(df["ID"][y],":",corpus[y])
                print("Cosine similarity:",cosine_similarity(X[x],X[y]))
                print()
# Out:
# 10 : Cancel ASN WMS Cancel ASN
# 13 : Cancel ASN WMS Cancel ASN
# Cosine similarity: [[1.]]
#
# 11 : MAXPREDO Validation is corect
# 14 : MAXPREDO Validation is right
# Cosine similarity: [[0.64183024]]
#
# 12 : Move to QC
# 17 : Move to QC
# Cosine similarity: [[1.]]
#
# 15 : Verify files are sent every hours for this interface from Optima
# 18 : Verify files are not sent
# Cosine similarity: [[0.44897995]]

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

cosine_similarity('cough','coughing')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-534b7c8a1e9b> in <module>
# ----> 1 cosine_similarity('cough','coughing')
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1178     # to avoid recursive import
#    1179
# -> 1180     X, Y = check_pairwise_arrays(X, Y)
#    1181
#    1182     X_normalized = normalize(X, copy=True)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     144                             estimator=estimator)
#     145     else:
# --> 146         X = check_array(X, accept_sparse=accept_sparse, dtype=dtype,
#     147                         copy=copy, force_all_finite=force_all_finite,
#     148                         estimator=estimator)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'cough'
